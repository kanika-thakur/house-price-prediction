# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("price.csv")
df
# Out:
#     bedrooms  washrooms  floors  area_sqft  parking       furnishing  \
# 0          3          2       2       1200        1  Fully-Furnished
# 1          2          1       1        850        0   Semi-Furnished
# 2          4          3       3       1800        2  Fully-Furnished
# 3          2          2       1        950        1      Unfurnished
# 4          3          2       2       1300        1   Semi-Furnished
# ..       ...        ...     ...        ...      ...              ...
# 68         1          1       1        530        0      Unfurnished
# 69         3          2       2       1400        1  Fully-Furnished
# 70         2          1       1        700        0   Semi-Furnished
# 71         3          2       2       1250        1  Fully-Furnished
# 72         4          3       3       2000        2  Fully-Furnished
#
#     year_built     price       city
# 0         2015   8500000     Mumbai
# 1         2008   4200000      Delhi
# 2         2010  12500000  Bangalore
# 3         2000   3800000    Chennai
# 4         2012   7500000  Hyderabad
# ..         ...       ...        ...
# 68        1991   2300000       Pune
# 69        2016   8900000    Kolkata
# 70        2007   3200000      Delhi
# 71        2013   7800000     Mumbai
# 72        2019  14000000  Bangalore
#
# [73 rows x 9 columns]

# %%
df.isnull() .sum()
# Out:
# bedrooms      0
# washrooms     0
# floors        0
# area_sqft     0
# parking       0
# furnishing    0
# year_built    0
# price         0
# city          0
# dtype: int64

# %%
le=LabelEncoder()

# %%
le = LabelEncoder()
df["furnishing"] = le.fit_transform(df["furnishing"])

# %%
df.head()
# Out:
#    bedrooms  washrooms  floors  area_sqft  parking  furnishing  year_built  \
# 0         3          2       2       1200        1           0        2015
# 1         2          1       1        850        0           1        2008
# 2         4          3       3       1800        2           0        2010
# 3         2          2       1        950        1           2        2000
# 4         3          2       2       1300        1           1        2012
#
#       price       city
# 0   8500000     Mumbai
# 1   4200000      Delhi
# 2  12500000  Bangalore
# 3   3800000    Chennai
# 4   7500000  Hyderabad

# %%
city_map = {
    "Bangalore": 0,
    "Chennai": 1,
    "Delhi": 2,
    "Hyderabad": 3,
    "Kolkata": 4,
    "Mumbai": 5,
    "Pune": 6
}

df["city"] = df["city"].map(city_map)

# %%
df
# Out:
#     bedrooms  washrooms  floors  area_sqft  parking  furnishing  year_built  \
# 0          3          2       2       1200        1           0        2015
# 1          2          1       1        850        0           1        2008
# 2          4          3       3       1800        2           0        2010
# 3          2          2       1        950        1           2        2000
# 4          3          2       2       1300        1           1        2012
# ..       ...        ...     ...        ...      ...         ...         ...
# 68         1          1       1        530        0           2        1991
# 69         3          2       2       1400        1           0        2016
# 70         2          1       1        700        0           1        2007
# 71         3          2       2       1250        1           0        2013
# 72         4          3       3       2000        2           0        2019
#
#        price  city
# 0    8500000     5
# 1    4200000     2
# 2   12500000     0
# 3    3800000     1
# 4    7500000     3
# ..       ...   ...
# 68   2300000     6
# 69   8900000     4
# 70   3200000     2
# 71   7800000     5
# 72  14000000     0
#
# [73 rows x 9 columns]

# %%
print(df.columns)
# Out:
# Index(['bedrooms', 'washrooms', 'floors', 'area_sqft', 'parking', 'furnishing',
#        'year_built', 'price', 'city'],
#       dtype='object')

# %%
df=df.astype(int)

# %%
df
# Out:
#     bedrooms  washrooms  floors  area_sqft  parking  furnishing  year_built  \
# 0          3          2       2       1200        1           0        2015
# 1          2          1       1        850        0           1        2008
# 2          4          3       3       1800        2           0        2010
# 3          2          2       1        950        1           2        2000
# 4          3          2       2       1300        1           1        2012
# ..       ...        ...     ...        ...      ...         ...         ...
# 68         1          1       1        530        0           2        1991
# 69         3          2       2       1400        1           0        2016
# 70         2          1       1        700        0           1        2007
# 71         3          2       2       1250        1           0        2013
# 72         4          3       3       2000        2           0        2019
#
#        price  city
# 0    8500000     5
# 1    4200000     2
# 2   12500000     0
# 3    3800000     1
# 4    7500000     3
# ..       ...   ...
# 68   2300000     6
# 69   8900000     4
# 70   3200000     2
# 71   7800000     5
# 72  14000000     0
#
# [73 rows x 9 columns]

# %%
x=df.drop("price", axis=1)
y=df["price"]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
y
# Out:
# 0      8500000
# 1      4200000
# 2     12500000
# 3      3800000
# 4      7500000
#         ...
# 68     2300000
# 69     8900000
# 70     3200000
# 71     7800000
# 72    14000000
# Name: price, Length: 73, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9740288741514547

# %%
accuracy_percent = r2 * 100
print("Accuracy (%):", accuracy_percent)
# Out:
# Accuracy (%): 97.40288741514547

# %%
df
# Out:
#     bedrooms  washrooms  floors  area_sqft  parking  furnishing  year_built  \
# 0          3          2       2       1200        1           0        2015
# 1          2          1       1        850        0           1        2008
# 2          4          3       3       1800        2           0        2010
# 3          2          2       1        950        1           2        2000
# 4          3          2       2       1300        1           1        2012
# ..       ...        ...     ...        ...      ...         ...         ...
# 68         1          1       1        530        0           2        1991
# 69         3          2       2       1400        1           0        2016
# 70         2          1       1        700        0           1        2007
# 71         3          2       2       1250        1           0        2013
# 72         4          3       3       2000        2           0        2019
#
#        price  city
# 0    8500000     5
# 1    4200000     2
# 2   12500000     0
# 3    3800000     1
# 4    7500000     3
# ..       ...   ...
# 68   2300000     6
# 69   8900000     4
# 70   3200000     2
# 71   7800000     5
# 72  14000000     0
#
# [73 rows x 9 columns]

# %%
x
# Out:
#     bedrooms  washrooms  floors  area_sqft  parking  furnishing  year_built  \
# 0          3          2       2       1200        1           0        2015
# 1          2          1       1        850        0           1        2008
# 2          4          3       3       1800        2           0        2010
# 3          2          2       1        950        1           2        2000
# 4          3          2       2       1300        1           1        2012
# ..       ...        ...     ...        ...      ...         ...         ...
# 68         1          1       1        530        0           2        1991
# 69         3          2       2       1400        1           0        2016
# 70         2          1       1        700        0           1        2007
# 71         3          2       2       1250        1           0        2013
# 72         4          3       3       2000        2           0        2019
#
#     city
# 0      5
# 1      2
# 2      0
# 3      1
# 4      3
# ..   ...
# 68     6
# 69     4
# 70     2
# 71     5
# 72     0
#
# [73 rows x 8 columns]

# %%
import joblib

# %%
joblib.dump(lr, "house5.pkl")
# Out:
# ['house5.pkl']

# %%
df
# Out:
#     bedrooms  washrooms  floors  area_sqft  parking  furnishing  year_built  \
# 0          3          2       2       1200        1           0        2015
# 1          2          1       1        850        0           1        2008
# 2          4          3       3       1800        2           0        2010
# 3          2          2       1        950        1           2        2000
# 4          3          2       2       1300        1           1        2012
# ..       ...        ...     ...        ...      ...         ...         ...
# 68         1          1       1        530        0           2        1991
# 69         3          2       2       1400        1           0        2016
# 70         2          1       1        700        0           1        2007
# 71         3          2       2       1250        1           0        2013
# 72         4          3       3       2000        2           0        2019
#
#        price  city
# 0    8500000     5
# 1    4200000     2
# 2   12500000     0
# 3    3800000     1
# 4    7500000     3
# ..       ...   ...
# 68   2300000     6
# 69   8900000     4
# 70   3200000     2
# 71   7800000     5
# 72  14000000     0
#
# [73 rows x 9 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Predicted_Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 7
#       4 plt.figure(figsize=(10, 6))
#       6 # Line chart
# ----> 7 plt.plot(df["year_built"], df["Predicted_Price"], marker='o', linestyle='-', color='b', label='Line Chart')
#       9 # Bar chart
#      10 plt.bar(df["year_built"] + 0.5, df["Predicted_Price"], width=2, alpha=0.5, color='orange', label='Bar Chart')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Predicted_Price'
